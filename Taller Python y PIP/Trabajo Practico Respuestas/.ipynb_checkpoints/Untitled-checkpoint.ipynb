# %% [markdown]
# # Trabajo practico N°2
# ## Taller Python y PIP
#
# ### 3)Utilice el comando pip para instalar el paquete Matplotlib e intente ejecute el archivo code/charts/line.py
#
# Instalé el paquete Matplotlib con el comando pip install Matplotlib, luego ejecuté el archivo line.py donde me aparece
#
# Line.py
#
# ![Captura%20de%20pantalla%20%2877%29.png](attachment:Captura%20de%20pantalla%20%2877%29.png)

# %% [markdown]
# ### 4)Pruebe con los demás gráficos.
# Bar.py
#
# ![Captura%20de%20pantalla%20%2878%29.png](attachment:Captura%20de%20pantalla%20%2878%29.png)

# %% [markdown]
# Pie.py
# ![Captura%20de%20pantalla%20%2879%29.png](attachment:Captura%20de%20pantalla%20%2879%29.png)

# %% [markdown]
# ### 5)Visualice el error generado por la falta de una librería. Pruebe desinstalar la librería Matplotlib y a continuación ejecute nuevamente el archivo line.py.
#
# Eliminé la librería Matplotlib con el comando pip uninstall Matplotlib y cuando quiero ejecutar el archivo line.py directamente no abren los graficos.

# %% [markdown]
# ### 6)Instale la librería Pandas en su equipo y ejecute el archivo guardando en code/data/pand.py
#
# Instalé el paquete Pandas con el comando pip install Pandas, luego ejecuté el archivo pand.py donde tuve q agregarle al código import msvcrt y msvcrt.getch() porque una vez ejecutado y terminado el programa se cerraba la terminal.

# %%
import pandas as pd
import msvcrt
df = pd.read_csv("dataset.csv", index_col="id")
print(df)
msvcrt.getch()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("dataset.csv", index_col="id")
#       4 print(df)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ![Captura%20de%20pantalla%20%2888%29.png](attachment:Captura%20de%20pantalla%20%2888%29.png)

# %% [markdown]
# ### 7)Agregue la línea df.describe() al archivo pand.py e imprima su resultado.
# ### ¿Qué muestra el resultado?

# %%
import pandas as pd
import msvcrt
df = pd.read_csv("dataset.csv", index_col="id")
print(df)
print(df.describe())
msvcrt.getch()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 import pandas as pd
#       2 import msvcrt
# ----> 3 df = pd.read_csv("dataset.csv", index_col="id")
#       4 print(df)
#       5 print(df.describe())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8)¿Qué resultado nos devuelve añadiendo la línea df.head()? ¿y df.tail()?

# %%
import pandas as pd
import msvcrt
df = pd.read_csv("dataset.csv", index_col="id")
print(df)
print(df.describe())
print( df.head())
msvcrt.getch()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import msvcrt
df = pd.read_csv("dataset.csv", index_col="id")
print(df)
print(df.describe())
print(df.head())
print(df.tail())
msvcrt.getch()

# %% [markdown]
# ![image.png](attachment:image.png)
